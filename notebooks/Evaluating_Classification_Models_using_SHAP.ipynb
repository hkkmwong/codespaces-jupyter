# %% [markdown]
# # Evaluating  Classification Models using SHAP
#
# The Project Development phase of the AI Lifecycle consists of the multiple steps.
#
# This demonstration will focus on achieving model interpretability through the SHAP (SHapley Additive exPlanations) package.
#
# Below sample code will build three common classication models on a tabular data set and use the SHAP package to explain the models:
# *   Logistic regession
# *   Tree-based model, XGBoost
# *   Neural Network

# %% [markdown]
# ---

# %% [markdown]
# # Business & Data Understanding

# %% [markdown]
# ## Objective
# - To predict whether an individual has above USD50K/year income based on census data.

# %% [markdown]
# ## Exploratory Data Analysis
#
# #### a. Data set
# - Adult Data Set
# - Source: https://archive.ics.uci.edu/ml/datasets/Adult
#
# #### b. Data Dictionary
# ##### Predictive Variables
# - **Age**: **continuous**.
# - **Workclass**: **categorical**. Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# - **education-num**: **continuous**. the highest level of education achieved in numerical form
# - **marital-status**: **categorical**. Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# - **occupation**: **categorical**. Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# - **relationship**: **categorical**. Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# - **race**: **categorical**. White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# - **sex**: **categorical**. Female, Male.
# - **capital-gain**: **continuous**. capital gains for an individual
# - **capital-loss**: **continuous**. capital loss for an individual
# - **hours-per-week**: **continuous**. the hours an individual has reported to work per week
# - **country**: **categorical**. United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong Kong , Holand-Netherlands.
#
# ##### Target Variable
# - **label**: **categorical**. Income >50K, <=50K.

# %% [markdown]
# ##  Install Libraries

# %%
# !pip install shap

# %% [markdown]
# # Preview dataset

# %%
import shap

X_display,y_display = shap.datasets.adult(display=True)
X_display.head()
# Out:
#     Age          Workclass  Education-Num       Marital Status  \
# 0  39.0          State-gov           13.0        Never-married
# 1  50.0   Self-emp-not-inc           13.0   Married-civ-spouse
# 2  38.0            Private            9.0             Divorced
# 3  53.0            Private            7.0   Married-civ-spouse
# 4  28.0            Private           13.0   Married-civ-spouse
#
#            Occupation    Relationship    Race      Sex  Capital Gain  \
# 0        Adm-clerical   Not-in-family   White     Male        2174.0
# 1     Exec-managerial         Husband   White     Male           0.0
# 2   Handlers-cleaners   Not-in-family   White     Male           0.0
# 3   Handlers-cleaners         Husband   Black     Male           0.0
# 4      Prof-specialty            Wife   Black   Female           0.0
#
#    Capital Loss  Hours per week         Country
# 0           0.0            40.0   United-States
# 1           0.0            13.0   United-States
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Pre-Processing

# %% [markdown]
# *   Encode categorical variables into numeric
# *   Split dataset into training set and test set

# %%
from sklearn.model_selection import train_test_split
X,y = shap.datasets.adult()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)

# %%
X.head()
# Out:
#     Age  Workclass  Education-Num  Marital Status  Occupation  Relationship  \
# 0  39.0          7           13.0               4           1             0
# 1  50.0          6           13.0               2           4             4
# 2  38.0          4            9.0               0           6             0
# 3  53.0          4            7.0               2           6             4
# 4  28.0          4           13.0               2          10             5
#
#    Race  Sex  Capital Gain  Capital Loss  Hours per week  Country
# 0     4    1        2174.0           0.0            40.0       39
# 1     4    1           0.0           0.0            13.0       39
# 2     4    1           0.0           0.0            40.0       39
# 3     2    1           0.0           0.0            40.0       39
# 4     2    0           0.0           0.0            40.0        5

# %% [markdown]
# ---

# %% [markdown]
# ## Model building

# %% [markdown]
# ### Census income classification with Linear models - Logistic regression

# %%
import shap
from sklearn.linear_model import LogisticRegression
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %% [markdown]
# #### Model Training
# Build a logistic regression model to make predictions on the targeted label.

# %%
model = LogisticRegression(solver='lbfgs',max_iter=400).fit(X_train, y_train)
y_pred = model.predict(X_test)

explainer = shap.Explainer(model, X, feature_names=X.columns)
shap_values = explainer(X)

# %% [markdown]
# #### Visualize a single prediction

# %% [markdown]
# For local intrepretations, we will focus on the first data sample.

# %%
shap.initjs()
shap.plots.force(shap_values[0])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %% [markdown]
# From the SHAP values, for this record, we can observe that Education and Capital Gain give the greatest Positive impacts to the prediction. On the other hand, Relationshop and Martial Status give the greatest Negative impacts to the prediction.

# %% [markdown]
# #### Summarize the effect of all the features

# %%
shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# From the SHAP values, we can observe that these features give the greatest impacts to the prediction.
#
#
# *   Relationship
# *   Marital Status
# *   Capital Gain
# *   Education

# %%
shap.plots.beeswarm(shap_values)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %% [markdown]
# From the SHAP values, we can observe that
#
# in general:
# - Higher value of Relationship, i.e. "Wife" and "Husband" will have higher chance of earning above USD50K/year income
# - Lower value of Marital Status, i.e. "Divorced" and "Married-AF-spouse" will have higher chance of earning above USD50K/year income
# - People with higher Capital Gain will have higher chance of earning above USD50K/year income
# - People with higher Education will have higher chance of earning above USD50K/year income

# %% [markdown]
# ---

# %% [markdown]
# ### Census income classification with Tree-based models - XGBoost
# load additional libraries for XGBoost model example

# %%
import xgboost
import numpy as np
import matplotlib.pylab as pl

# %% [markdown]
# #### Load dataset

# %%
d_train = xgboost.DMatrix(X_train, label=y_train)
d_test = xgboost.DMatrix(X_test, label=y_test)

# %% [markdown]
# #### Model Training

# %%
params = {
    "eta": 0.01,
    "objective": "binary:logistic",
    "subsample": 0.5,
    "base_score": np.mean(y_train),
    "eval_metric": "logloss"
}
model = xgboost.train(params, d_train, 5000, evals = [(d_test, "test")], verbose_eval=100, early_stopping_rounds=20)
# Out:
# [0]	test-logloss:0.54663
# [100]	test-logloss:0.36373
# [200]	test-logloss:0.31793
# [300]	test-logloss:0.30061
# [400]	test-logloss:0.29207
# [500]	test-logloss:0.28678
# [600]	test-logloss:0.28381
# [700]	test-logloss:0.28181
# [800]	test-logloss:0.28064
# [900]	test-logloss:0.27992
# [1000]	test-logloss:0.27928
# [1018]	test-logloss:0.27935

# %% [markdown]
# #### Visualize a single prediction

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

# %%
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values[0,:], X.iloc[0,:])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %% [markdown]
# From the SHAP values, for this record, we can observe that Education gives the greatest positive impacts to the prediction. On the other hand, Relationship and Capital Gain give the greatest negative impacts to the prediction.

# %% [markdown]
# #### Summarize the effect of all the features

# %%
shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# From the SHAP values, we can observe that these features give the greatest impacts to the prediction.
#
#
# *   Relationship
# *   Age
# *   Education
# *   Capital Gain

# %%
shap.summary_plot(shap_values, X)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %% [markdown]
# From the SHAP values, we can observe that
#
# in general:
# - Higher value of Relationship, i.e. "Wife" and "Husband" will have higher chance of earning above USD50K/year income
# - Young people will have higher chance of earning below USD50K/year income
# - People with higher Education will have higher chance of earning above USD50K/year income

# %% [markdown]
# ---

# %% [markdown]
# ### Census income classification with Neural networks - Keras
#
# load additional libraries for Neural Network model example

# %%
from keras.layers import Input, Dense, Flatten, Concatenate, concatenate, Dropout, Lambda
from keras.models import Model
from tensorflow.python.keras.layers.embeddings import Embedding
from tqdm import tqdm
import shap
import numpy as np
import random

# %% [markdown]
# #### Load dataset

# %%
# normalize data (this is important for model convergence)
dtypes = list(zip(X.dtypes.index, map(str, X.dtypes)))

for k,dtype in dtypes:
    if dtype == "float32":
        X[k] -= X[k].mean()
        X[k] /= X[k].std()

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=7)

# %% [markdown]
# #### Train the model

# %%
# build model
input_els = []
encoded_els = []
for k,dtype in dtypes:
    input_els.append(Input(shape=(1,)))
    if dtype == "int8":
        e = Flatten()(Embedding(X_train[k].max()+1, 1)(input_els[-1]))
    else:
        e = input_els[-1]
    encoded_els.append(e)
encoded_els = concatenate(encoded_els)
layer1 = Dropout(0.5)(Dense(100, activation="relu")(encoded_els))
out = Dense(1)(layer1)

# train model
regression = Model(inputs=input_els, outputs=[out])
regression.compile(optimizer="adam", loss='binary_crossentropy')
regression.fit(
    [X_train[k].values for k,t in dtypes],
    y_train,
    epochs=50,
    batch_size=512,
    shuffle=True,
    validation_data=([X_valid[k].values for k,t in dtypes], y_valid)
)
# Out:
# WARNING:tensorflow:The following Variables were used in a Lambda layer's call (tf.compat.v1.nn.embedding_lookup), but are not present in its tracked objects:   <tf.Variable 'embedding/embeddings:0' shape=(9, 1) dtype=float32>. This is a strong indication that the Lambda layer should be rewritten as a subclassed Layer.
# WARNING:tensorflow:The following Variables were used in a Lambda layer's call (tf.compat.v1.nn.embedding_lookup_1), but are not present in its tracked objects:   <tf.Variable 'embedding_1/embeddings:0' shape=(7, 1) dtype=float32>. This is a strong indication that the Lambda layer should be rewritten as a subclassed Layer.
# WARNING:tensorflow:The following Variables were used in a Lambda layer's call (tf.compat.v1.nn.embedding_lookup_2), but are not present in its tracked objects:   <tf.Variable 'embedding_2/embeddings:0' shape=(15, 1) dtype=float32>. This is a strong indication that the Lambda layer should be rewritten as a subclassed Layer.
# ...

# %% [markdown]
# #### Explain predictions
#
# SHAP expects model functions to take a 2D numpy array as input, so we define a wrapper function around the original Keras predict function.

# %%
def f(X):
    return regression.predict([X[:,i] for i in range(X.shape[1])]).flatten()

# %% [markdown]
# #### Visualize a single prediction
#
# 50 samples from dataset will be used to represent "typical" features values, 500 peterbation samples will be used to estimate the SHAP values for a given prediction.

# %%
explainer = shap.KernelExplainer(f, X.iloc[:50,:])
shap_values = explainer.shap_values(X.iloc[0,:], nsamples=500)
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values, X.iloc[0,:])
# Out:
# ...
# 782/782 [==============================] - 1s 1ms/step
# ...

# %% [markdown]
# From the SHAP values, for this record, we can observe that Education and Age give the greatest positive impacts to the prediction. On the other hand, Relationship gives the greatest negative impacts to the prediction.

# %%
random_index = random.sample(range(0, len(X)-1), 1000)
random_index.sort()

# %%
shap_values_nn = explainer.shap_values(X.iloc[random_index,:], nsamples=500)
# Out:
# ...
#  30%|███       | 304/1000 [08:53<20:29,  1.77s/it]
# ...
# ...
# 100%|██████████| 1000/1000 [28:58<00:00,  1.74s/it]

# %% [markdown]
# Remarks: As it will take long time for calculating SHAP value for all records in the dataset, we only pick 1000 samples from the dataset to calculate the SHAP values and generate the summary plot

# %% [markdown]
# #### Summarize the effect of all the features

# %%
shap.summary_plot(shap_values_nn, X.iloc[random_index,:], plot_type="bar")

# %% [markdown]
# From the SHAP values, we can observe that These features gives the greatest impacts to the prediction.
#
#
# *   Relationship
# *   Age
# *   Hours per week
# *   Education
# *   Capital Gain

# %%
shap.summary_plot(shap_values_nn, X.iloc[random_index,:])
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %% [markdown]
# From the SHAP values, we can observe that
#
# in general:
# - Higher value of Relationship, i.e. "Wife" and "Husband" will have higher chance of earning above USD50K/year income
# - Lower value of Age will have higher chance of earning below USD50K/year income
# - Peopel worked fewer hours per week will have higher chance of earning below USD50K/year income
# - People with higher Education will have higher chance of earning above USD50K/year income

# %% [markdown]
# ---
